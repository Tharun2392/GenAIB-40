# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharun2392/GenAIB-40/blob/main/GEN_AI_LAB_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adadelta

# Loading MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0  # Normalizing the data
x_test = x_test / 255.0  # Normalizing the data

# Convert labels to categorical (one-hot encoding)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Function to create the ANN model
def create_ann(hidden_layers, hidden_neurons, activation_function):
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))  # Input layer
    for _ in range(hidden_layers):
        model.add(Dense(hidden_neurons, activation=activation_function))  # Hidden layers
    model.add(Dense(10, activation='softmax'))  # Output layer
    return model

# Creating the initial model with given architecture
hidden_layers = 3
hidden_neurons = 32
activation_function = 'relu'
model = create_ann(hidden_layers, hidden_neurons, activation_function)

# Compiling the model
model.compile(optimizer=Adadelta(), loss='categorical_crossentropy', metrics=['accuracy'])

# Training the model
epochs = 10
batch_size = 128
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test))

# Evaluate accuracy with training and testing data
train_loss, train_accuracy = model.evaluate(x_train, y_train)
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Testing Accuracy: {test_accuracy:.2f}")

# Experiment with different architectures
architectures = [
    {'hidden_layers': 2, 'hidden_neurons': 64, 'activation_function': 'relu'},
    {'hidden_layers': 4, 'hidden_neurons': 128, 'activation_function': 'sigmoid'}
]

best_accuracy = 0
best_model = None

for arch in architectures:
    model = create_ann(arch['hidden_layers'], arch['hidden_neurons'], arch['activation_function'])
    model.compile(optimizer=Adadelta(), loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test))
    _, test_accuracy = model.evaluate(x_test, y_test)
    print(f"Architecture: {arch}, Testing Accuracy: {test_accuracy:.2f}")

    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_model = arch

print(f"Best Architecture: {best_model}, Best Testing Accuracy: {best_accuracy:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.0893 - loss: 2.3369 - val_accuracy: 0.0951 - val_loss: 2.3148
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0925 - loss: 2.3161 - val_accuracy: 0.1075 - val_loss: 2.2954
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1037 - loss: 2.2986 - val_accuracy: 0.1261 - val_loss: 2.2789
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1231 - loss: 2.2816 - val_accuracy: 0.1464 - val_loss: 2.2645
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.1433 - loss: 2.2679 - val_accuracy: 0.1640 - val_loss: 2.2514
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1612 - loss: 2.2543 - val_accuracy: 0.1778 - val_loss: 2.2388
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1708 - loss: 2.2422 - val_accuracy: 0.1871 - val_loss: 2.2264
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1828 - loss: 2.2295 - val_accuracy: 0.1960 - val_loss: 2.2142
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1888 - loss: 2.2195 - val_accuracy: 0.2038 - val_loss: 2.2018
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1962 - loss: 2.2055 - val_accuracy: 0.2119 - val_loss: 2.1891
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.1986 - loss: 2.1960
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2108 - loss: 2.1974
# Training Accuracy: 0.20
# Testing Accuracy: 0.21
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0783 - loss: 2.3115 - val_accuracy: 0.1083 - val_loss: 2.2788
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1049 - loss: 2.2757 - val_accuracy: 0.1440 - val_loss: 2.2407
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1381 - loss: 2.2378 - val_accuracy: 0.1843 - val_loss: 2.2039
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.1820 - loss: 2.2011 - val_accuracy: 0.2259 - val_loss: 2.1680
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.2224 - loss: 2.1678 - val_accuracy: 0.2642 - val_loss: 2.1324
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2656 - loss: 2.1322 - val_accuracy: 0.3042 - val_loss: 2.0970
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3013 - loss: 2.0991 - val_accuracy: 0.3343 - val_loss: 2.0615
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.3350 - loss: 2.0645 - val_accuracy: 0.3728 - val_loss: 2.0258
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3671 - loss: 2.0282 - val_accuracy: 0.4076 - val_loss: 1.9896
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3991 - loss: 1.9923 - val_accuracy: 0.4351 - val_loss: 1.9529
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4270 - loss: 1.9770
# Architecture: {'hidden_layers': 2, 'hidden_neurons': 64, 'activation_function': 'relu'}, Testing Accuracy: 0.44
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1122 - loss: 2.5587 - val_accuracy: 0.1135 - val_loss: 2.5184
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.1119 - loss: 2.5036 - val_accuracy: 0.1135 - val_loss: 2.4679
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1106 - loss: 2.4609 - val_accuracy: 0.1135 - val_loss: 2.4266
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1121 - loss: 2.4191 - val_accuracy: 0.1135 - val_loss: 2.3942
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.1140 - loss: 2.3880 - val_accuracy: 0.1135 - val_loss: 2.3691
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1158 - loss: 2.3611 - val_accuracy: 0.1135 - val_loss: 2.3504
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1112 - loss: 2.3491 - val_accuracy: 0.1135 - val_loss: 2.3367
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.1139 - loss: 2.3349 - val_accuracy: 0.1135 - val_loss: 2.3266
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1099 - loss: 2.3269 - val_accuracy: 0.1135 - val_loss: 2.3192
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1117 - loss: 2.3181 - val_accuracy: 0.1135 - val_loss: 2.3139
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1160 - loss: 2.3129
# Architecture: {'hidden_layers': 4, 'hidden_neurons': 128, 'activation_function': 'sigmoid'}, Testing Accuracy: 0.11
# Best Architecture: {'hidden_layers': 2, 'hidden_neurons': 64, 'activation_function': 'relu'}, Best Testing Accuracy: 0.44
